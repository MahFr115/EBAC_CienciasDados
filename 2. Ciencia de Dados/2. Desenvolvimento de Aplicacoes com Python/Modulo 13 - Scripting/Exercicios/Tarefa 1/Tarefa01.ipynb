# %% [markdown]
# #### Crie um jupyter notebook com os imports necessários e um código para gerar os gráficos referentes a base de dados de março, abril, maio, junho e dezembro (numa célula só ou em várias).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

def nome_arquivo():
    estado = input("Sigla do estado da análise: ").upper()  # Convertendo para maiúsculas
    mês = input("Nome do mês do relatório: ").upper()  # Convertendo para maiúsculas
    ano = input("Ano do relatório (AAAA): ")  # Mantendo como string para formatação correta

    meses = {
        'JANEIRO': 'JAN', 'FEVEREIRO': 'FEV', 'MARÇO': 'MAR', 'ABRIL': 'ABR',
        'MAIO': 'MAI', 'JUNHO': 'JUN', 'JULHO': 'JUL', 'AGOSTO': 'AGO',
        'SETEMBRO': 'SET', 'OUTUBRO': 'OUT', 'NOVEMBRO': 'NOV', 'DEZEMBRO': 'DEZ'
    }

    if mês in meses:
        mês = meses[mês]
    else:
        print("Mês inválido!")
        return None  

    arquivo = f'./input/SINASC_{estado}_{ano}_{mês}.csv'
    return arquivo  

sinasc = pd.read_csv(nome_arquivo())
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# Sigla do estado da análise:  ro
# Nome do mês do relatório:  março
# Ano do relatório (AAAA):  2019
# 2019-01-01 2019-03-31
# 2019-03

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

def nome_arquivo():
    estado = input("Sigla do estado da análise: ").upper()  # Convertendo para maiúsculas
    mês = input("Nome do mês do relatório: ").upper()  # Convertendo para maiúsculas
    ano = input("Ano do relatório (AAAA): ")  # Mantendo como string para formatação correta

    meses = {
        'JANEIRO': 'JAN', 'FEVEREIRO': 'FEV', 'MARÇO': 'MAR', 'ABRIL': 'ABR',
        'MAIO': 'MAI', 'JUNHO': 'JUN', 'JULHO': 'JUL', 'AGOSTO': 'AGO',
        'SETEMBRO': 'SET', 'OUTUBRO': 'OUT', 'NOVEMBRO': 'NOV', 'DEZEMBRO': 'DEZ'
    }

    if mês in meses:
        mês = meses[mês]
    else:
        print("Mês inválido!")
        return None  

    arquivo = f'./input/SINASC_{estado}_{ano}_{mês}.csv'
    return arquivo  

sinasc = pd.read_csv(nome_arquivo())
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# Sigla do estado da análise:  RO
# Nome do mês do relatório:  AbRil
# Ano do relatório (AAAA):  2019
# 2019-01-01 2019-04-30
# 2019-04

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

def nome_arquivo():
    estado = input("Sigla do estado da análise: ").upper()  # Convertendo para maiúsculas
    mês = input("Nome do mês do relatório: ").upper()  # Convertendo para maiúsculas
    ano = input("Ano do relatório (AAAA): ")  # Mantendo como string para formatação correta

    meses = {
        'JANEIRO': 'JAN', 'FEVEREIRO': 'FEV', 'MARÇO': 'MAR', 'ABRIL': 'ABR',
        'MAIO': 'MAI', 'JUNHO': 'JUN', 'JULHO': 'JUL', 'AGOSTO': 'AGO',
        'SETEMBRO': 'SET', 'OUTUBRO': 'OUT', 'NOVEMBRO': 'NOV', 'DEZEMBRO': 'DEZ'
    }

    if mês in meses:
        mês = meses[mês]
    else:
        print("Mês inválido!")
        return None  

    arquivo = f'./input/SINASC_{estado}_{ano}_{mês}.csv'
    return arquivo  

sinasc = pd.read_csv(nome_arquivo())
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# Sigla do estado da análise:  Ro
# Nome do mês do relatório:  MAIO
# Ano do relatório (AAAA):  2019
# 2019-01-01 2019-05-31
# 2019-05

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

def nome_arquivo():
    estado = input("Sigla do estado da análise: ").upper()  # Convertendo para maiúsculas
    mês = input("Nome do mês do relatório: ").upper()  # Convertendo para maiúsculas
    ano = input("Ano do relatório (AAAA): ")  # Mantendo como string para formatação correta

    meses = {
        'JANEIRO': 'JAN', 'FEVEREIRO': 'FEV', 'MARÇO': 'MAR', 'ABRIL': 'ABR',
        'MAIO': 'MAI', 'JUNHO': 'JUN', 'JULHO': 'JUL', 'AGOSTO': 'AGO',
        'SETEMBRO': 'SET', 'OUTUBRO': 'OUT', 'NOVEMBRO': 'NOV', 'DEZEMBRO': 'DEZ'
    }

    if mês in meses:
        mês = meses[mês]
    else:
        print("Mês inválido!")
        return None  

    arquivo = f'./input/SINASC_{estado}_{ano}_{mês}.csv'
    return arquivo  

sinasc = pd.read_csv(nome_arquivo())
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# Sigla do estado da análise:  rO
# Nome do mês do relatório:  jUNhO
# Ano do relatório (AAAA):  2019
# 2019-01-01 2019-06-30
# 2019-06

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

def nome_arquivo():
    estado = input("Sigla do estado da análise: ").upper()  # Convertendo para maiúsculas
    mês = input("Nome do mês do relatório: ").upper()  # Convertendo para maiúsculas
    ano = input("Ano do relatório (AAAA): ")  # Mantendo como string para formatação correta

    meses = {
        'JANEIRO': 'JAN', 'FEVEREIRO': 'FEV', 'MARÇO': 'MAR', 'ABRIL': 'ABR',
        'MAIO': 'MAI', 'JUNHO': 'JUN', 'JULHO': 'JUL', 'AGOSTO': 'AGO',
        'SETEMBRO': 'SET', 'OUTUBRO': 'OUT', 'NOVEMBRO': 'NOV', 'DEZEMBRO': 'DEZ'
    }

    if mês in meses:
        mês = meses[mês]
    else:
        print("Mês inválido!")
        return None  

    arquivo = f'./input/SINASC_{estado}_{ano}_{mês}.csv'
    return arquivo  

sinasc = pd.read_csv(nome_arquivo())
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# Sigla do estado da análise:  ro
# Nome do mês do relatório:  deZemBRO
# Ano do relatório (AAAA):  2019
# 2019-01-01 2019-12-31
# 2019-12

# %% [markdown]
# #### Como que você poderia fazer para deixar isso mais automatizado? Descreva na última célula do jupyter notebook o que ajudaria na hora de gerar novos gráficos pros meses/anos seguintes.

# %% [markdown]
# Para automatizar os relatórios posteriores posso criar uma lista com os estados, meses e anos desejados, inseridos pelo usuário. Utilizando as seguintes alterações no código:automate. Outra forma seria criar relatórios no Power BI em que apenas precisariamos acrescentar a base de dados no arquivo

# %% [markdown]
# def nome_arquivos():<br>
#     meses_dict = {
#         'JANEIRO': 'JAN', 'FEVEREIRO': 'FEV', 'MARÇO': 'MAR', 'ABRIL': 'ABR',
#         'MAIO': 'MAI', 'JUNHO': 'JUN', 'JULHO': 'JUL', 'AGOSTO': 'AGO',
#         'SETEMBRO': 'SET', 'OUTUBRO': 'OUT', 'NOVEMBRO': 'NOV', 'DEZEMBRO': 'DEZ'
#     }
# <br>
#    arquivos = []<br>
# <br>
#    while True:<br>
#         estado = input("Sigla do estado da análise: ").upper()<br>
#         mês = input("Nome do mês do relatório: ").upper()<br>
#         ano = input("Ano do relatório (AAAA): ")<br>
# <br>
#    if estado == "0" or mês == "0" or ano == "0":<br>
#             print("Encerrando entrada de dados...")<br>
#             break<br>
# <br>
#    if mês not in meses_dict:<br>
#             print("Mês inválido! Tente novamente.")<br>
#             continue<br>
# <br>
#    arquivo = f'./input/SINASC_{estado}_{ano}_{meses_dict[mês]}.csv'<br>
#    arquivos.append(arquivo)<br>
#    print(f"Arquivo adicionado: {arquivo}")<br>
# <br>
#    return arquivos<br>
# <br>
# Obtém a lista de arquivos<br>
# arquivos = nome_arquivos()<br>
# <br>
# Processa cada arquivo separadamente<br>
# for arquivo in arquivos:<br>
#     try:<br>
#         sinasc = pd.read_csv(arquivo)<br>
#         print(f"Processando {arquivo}...")<br>
# <br>
#    Obtém o período do relatório<br>
#         max_data = sinasc.DTNASC.max()[:7]<br>
#         os.makedirs(f'./output/figs/{max_data}', exist_ok=True)<br>
# <br>
#    Geração de gráficos e salvamento dos relatórios (sem alterações)<br>
# <br>
#    print(f"Relatórios gerados para {arquivo} em ./output/figs/{max_data}")<br>
# <br>
#    except FileNotFoundError:<br>
#         print(f"Arquivo não encontrado: {arquivo}")<br>
#    except Exception as e:<br>
#         print(f"Erro ao processar {arquivo}: {e}")

# %% [markdown]
# Outra forma de otimização desse relatório que poderia utlizar seria criando uma macro no próprio excel ou uma rotina no power automate. Outra forma seria criar relatórios no Power BI em que apenas precisariamos acrescentar a base de dados no arquivo
